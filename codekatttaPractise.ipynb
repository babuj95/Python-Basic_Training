# %% [markdown]
# # Reverse a number

# %%
number=int(input())
for i in str(number)[::-1]:
        print(i, end="")
# Out:
# 4521

# %%
number=int(input())
rn=str(number)[::-1]
print(int(rn))
# Out:
# 65321

# %%
n=[1,2,3,15,4,5]
a=0
for i in n:
   if a<=i:
    a=i 
    print(1)
   else:
    break
print(n.index(a))
# Out:
# 3

# %%
ni=[1,2,3,15,4]
n=len(ni)
v=[]
for i in  range(n-1):
    if( ni[i] > ni[i+1]):
        v.append(i)
print(v)
a=len(v)
print(a)
if a==0:
    print(-1)
elif a>1:
    print(-1)
else:
    print(ni[v])



#violations = [i for i in range(n - 1) if ni[i] > ni[i + 1]]
#print(violations)
# Out:
# [3]
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 15
#      11     print(-1)
#      12 elif a>1:
#      13     print(-1)
#      14 else:
# ---> 15     print(ni[v])
#      16
#      17
#      18
#
# TypeError: list indices must be integers or slices, not list

# %% [markdown]
# # Multiple of 2 numbers and mod of 3rd number  (a*b)%c

# %%
a,b,c=list(map(int,input().split()))

a=int(a)
b=int(b)
c=int(c)

print((a*b) % c)
# Out:
# 1
# 4 3 11

# %% [markdown]
# # product of given number

# %%
n=int(input())
a=1
if  n <= 100000000000:
 for i in str(n):
     a *=(int(i))
 print(a)
# Out:
# 6

# %% [markdown]
# # Minimum of given numbers

# %%
a=input().split()
at=[int(i) for i in a]
print(min(at))
# Out:
# 0
