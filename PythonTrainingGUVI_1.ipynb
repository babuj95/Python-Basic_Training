# %% [markdown]
# <a href="https://colab.research.google.com/github/babuj95/Python-Basic_Training/blob/main/PythonTrainingGUVI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  Print

# %%
def test():
  try:
    return 10
  finally:
    return 20
print(test())
# Out:
# 20

# %%
def test():
  try:
    return 10
  finally:
    print ("hello")
print(test())
# Out:
# hello
# 10

# %%
name=""
if name=="rena":
   print("goat")
elif name:
  print("uyhgb")
else:
  print("hbcjb")
# Out:
# hbcjb

# %%
x=(1,)
print(x)
print(type(x))
# Out:
# (1,)
# <class 'tuple'>

# %%
def test():
  try:
    print("yuo")
  finally:
    print("hell")
print(test())
# Out:
# yuo
# hell
# None

# %%
print("Hello world") # when to use
print("hello, 'Babu'")
# Out:
# Hello world
# hello, 'Babu'

# %%
print('Hello world')
print('hello,"Babu"')
# Out:
# Hello world
# hello,"Babu"

# %% [markdown]
# # Variables -25-08-2026

# %%
type(name)
# Out:
# str

# %%
name="Babu"
subject="'Guvi"
age=30
salary=30000.01
Eligibile_for_licence=True

# %% [markdown]
# # Input

# %%
name = input("Enter your Name ")
age = int(input("Enter your Name "))
# Out:
# Enter your Name Babu
# Enter your Name 30

# %%
print("Name : ",name)
print("Age : ",age)
print(f"Hi, {name} you are {age} years old.") #It is called formated string to add variable inbetween a message
print("Type of Name : ",type(name))
print("Type of age  : ",type(age))
# Out:
# Name :  Babu
# Age :  30
# Hi, Babu you are 30 years old.
# Type of Name :  <class 'str'>
# Type of age  :  <class 'int'>

# %%
#Test
name = input("Enter your Name ")
salary = int(input("Enter your Salary "))
print(f"Hi, {name} you salary is {salary}.")
# Out:
# Enter your Name babu
# Enter your Salary 3490
# Hi, babu you salary is 3490.

# %% [markdown]
# # Arithmetic operators -27-08-2026

# %%
print(10+3)
print(3-2)
print(3*2)
print(4/2)
print(4//2) #---Floor value
print(4%2)  #---modulas
# Out:
# 13
# 1
# 6
# 2.0
# 2
# 0

# %%
x = 100
x -= 40
x *= 2
x **= 3
print(x)
x %=2
print(x)
# Out:
# 1728000
# 0

# %% [markdown]
# # Comparison Operator

# %% [markdown]
# Always return boolean value(true or false)

# %%
value1=1
value2=2
value1==value2   #Comparison
# Out:
# False

# %%
value1<value2    #lesser
# Out:
# True

# %%
value1>value2
# Out:
# False

# %%
value1 != value2
# Out:
# True

# %% [markdown]
# Logical# New Section

# %% [markdown]
# # Logical Operator  And, OR ,Not true

# %%
x=5
x<6 and x>1  #and
# Out:
# True

# %%
x<6 or x>10   #or
# Out:
# True

# %%
not(x<6) and not(x>1)  #not
# Out:
# False

# %%
not(x<1) and not(x>10)
# Out:
# True

# %% [markdown]
# # Identity Operator

# %%
a=[1,2,3,4]  #Identity Operator
b=a
b is a
# Out:
# True

# %%
c=[1,2,3,4]
c is not a   #only verify memory for list
# Out:
# True

# %% [markdown]
# # Membership operator

# %%
'ap' in 'apple'
# Out:
# True

# %%
3 in [1,2,3,4]
# Out:
# True

# %%
'a' in 'apple' and 'z' in 'apple'
# Out:
# False

# %% [markdown]
# # Operator Precedence

# %% [markdown]
# 1.bracket
# 2.multiple
# 3.add/sub
# 4.
